# %% [markdown]
# Use this notebook to run experiments and plot results easily. You do not need to submit it, but you may use some of the generated plots in your report.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import utils
import numpy as np
import pandas as pd
from knn import KNN
import sklearn
import matplotlib.pyplot as plt

# %%
# # Read the training CSV file into a DataFrame
# file_path = 'training.csv'  # Replace with the actual file path
# df = pd.read_csv('C:\\Users\\33681\\OneDrive\\Documents\\MALIS\\malis1\\data\\validation.csv' )


# # Separate the data into X1, X2, and y
# X1 = df['X1']
# X2 = df['X2']
# y = df['y']

# # Create a scatter plot
# plt.figure(figsize=(8, 6))
# plt.scatter(X1, X2, c=y, cmap='viridis', marker='o', edgecolor='k')
# plt.xlabel('X1')
# plt.ylabel('X2')
# plt.title('Scatter Plot of X1 vs X2')
# plt.colorbar(label='y')
# plt.grid(True)
# plt.show()
# # Read the CSV file into a DataFrame
# file_path = 'training.csv'  # Replace with the actual file path
# df = pd.read_csv('C:\\Users\\33681\\OneDrive\\Documents\\MALIS\\malis1\\code\\training.csv' )


# # Separate the data into X1, X2, and y
# X1 = df['X1']
# X2 = df['X2']
# y = df['y']

# # Create a scatter plot
# plt.figure(figsize=(8, 6))
# plt.scatter(X1, X2, c=y, cmap='viridis', marker='o', edgecolor='k')
# plt.xlabel('X1')
# plt.ylabel('X2')
# plt.title('Scatter Plot of X1 vs X2')
# plt.colorbar(label='y')
# plt.grid(True)
# plt.show()

# %%
df_input = pd.read_csv('training.csv', sep=',')
X, y = df_input[['X1', 'X2']].values, df_input['y'].values

# Create a grid of testing points
h=.02 # space in the gri

x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
# xx is the x-axis coordinate of the points in the test set
# yy is the y-axis coordinate of the points in the test set
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
# X_test contains the test set inputs (xx,yy)
X_test = np.c_[xx.ravel(), yy.ravel()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\33681\OneDrive\Documents\MALIS\malis1\code\experiments.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/33681/OneDrive/Documents/MALIS/malis1/code/experiments.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> df_input = pd.read_csv('training.csv', sep=',')
#       <a href='vscode-notebook-cell:/c%3A/Users/33681/OneDrive/Documents/MALIS/malis1/code/experiments.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> X, y = df_input[['X1', 'X2']].values, df_input['y'].values
#       <a href='vscode-notebook-cell:/c%3A/Users/33681/OneDrive/Documents/MALIS/malis1/code/experiments.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> # Create a grid of testing points
#
# NameError: name 'pd' is not defined

# %% [markdown]
# You can use the routine below to plot your results. Be careful to respect the naming conventions of the variables. This means X - training inputs, y - training labels, X_test - test inputs and y_test - predicted labels

# %%
# Parameter K defining the KNN algorithm
k=3
# Create a model for the KNN with inputs the ones from the gaussians and test the model using the grid of testing points
knn_model_k3 = KNN(k)
knn_model_k3.train(X, y)
y_test_k3=knn_model_k3.predict(X_test,2)
# Put the result into a color plot
y_test_k3 = y_test_k3.reshape(xx.shape)
utils.plot_results(xx,yy, X, y, y_test_k3, "k=" + str(k))

# %%
# Parameter K defining the KNN algorithm
k=20
from sklearn.metrics import accuracy_score

# Create a model for the KNN with inputs the ones from the gaussians and test the model using the grid of testing points
knn_model_k3 = KNN(k)
knn_model_k3.train(X, y)
y_val_k3=knn_model_k3.predict(X_val,2)
# Put the result into a color plot
# y_test_k3 = y_test_k3.reshape(xx.shape)
# utils.plot_results(xx_val, yy_val, X, y, y_val_k3, "k=" + str(k))

# making our predictions
# predictions = k_nearest_neighbor(X_train, y_train, X_test, 7)

# evaluating accuracy
accuracy = accuracy_score(y_val, y_val_k3)
print("The accuracy of our classifier is {}".format(100*accuracy))
# Out:
# The accuracy of our classifier is 81.25

# %%
# evaluating accuracy
y_test_k3=knn_model_k3.predict(X_test,2)
# Put the result into a color plot
y_test_k3 = y_test_k3.reshape(xx.shape)
accuracy = accuracy_score(y, y_test_k3)
print("The accuracy of our classifier is {}".format(100*accuracy))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\33681\OneDrive\Documents\MALIS\malis1\code\experiments.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/33681/OneDrive/Documents/MALIS/malis1/code/experiments.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> # evaluating accuracy
# ----> <a href='vscode-notebook-cell:/c%3A/Users/33681/OneDrive/Documents/MALIS/malis1/code/experiments.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> y_test_k3=knn_model_k3.predict(X_test,2)
#       <a href='vscode-notebook-cell:/c%3A/Users/33681/OneDrive/Documents/MALIS/malis1/code/experiments.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> # Put the result into a color plot
#       <a href='vscode-notebook-cell:/c%3A/Users/33681/OneDrive/Documents/MALIS/malis1/code/experiments.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> y_test_k3 = y_test_k3.reshape(xx.shape)
#
# NameError: name 'knn_model_k3' is not defined

# %%
# from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split
df_input = pd.read_csv('training.csv', sep=',')
X, y = df_input[['X1', 'X2']].values, df_input['y'].values

# create design matrix X and target vector y
# X = np.array(df.ix[:, 0:4])  # end index is exclusive
# y = np.array(df['class'])    # another way of indexing a pandas df

# split into train and test
X_train, \
X_test, \
y_train, \
y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\33681\OneDrive\Documents\MALIS\malis1\code\experiments.ipynb Cell 7 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/33681/OneDrive/Documents/MALIS/malis1/code/experiments.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> # from sklearn.cross_validation import train_test_split
#       <a href='vscode-notebook-cell:/c%3A/Users/33681/OneDrive/Documents/MALIS/malis1/code/experiments.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> from sklearn.model_selection import train_test_split
# ----> <a href='vscode-notebook-cell:/c%3A/Users/33681/OneDrive/Documents/MALIS/malis1/code/experiments.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> df_input = pd.read_csv('training.csv', sep=',')
# ...

# %%
# import sklearn
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# instantiate learning model (k = 3)
knn = KNeighborsClassifier(n_neighbors=3)

# fitting the model
knn.fit(X_train, y_train)

# predict the response
pred = knn.predict(X_test)

# evaluate accuracy
print("accuracy: {}".format(accuracy_score(y_test, pred)))
# Out:
# accuracy: 0.7261904761904762
